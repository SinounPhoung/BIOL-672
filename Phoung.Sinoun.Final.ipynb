# %%
import numpy as np 
import matplotlib.pyplot as plt 
import pandas as pd

# %%
data = pd.read_excel("Energy Model Data.xlsx", index_col=0)
data
# Out:
#       Energy Consumption (Trillion BTU/ yr)  Population (person)  \
# 2003                                   7233            290107933
# 2004                                   6987            292805298
# 2005                                   6901            295516599
# 2006                                   6155            298379912
# 2007                                   6589            301231207
# 2008                                   6889            304093966
# 2009                                   6637            306771529
# 2010                                   6641            309321666
# 2011                                   6473            311556874
# 2012                                   5684            313830990
# 2013                                   6689            315993715
# 2014                                   7006            318301008
# 2015                                   6465            320635163
# ...

# %%
X = data.drop("Energy Consumption (Trillion BTU/ yr)", axis=1)
y = data["Energy Consumption (Trillion BTU/ yr)"]

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols
model = ols("y ~ X", data).fit()

# %%
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.979
# Model:                            OLS   Adj. R-squared:                  0.972
# Method:                 Least Squares   F-statistic:                     140.5
# Date:                Tue, 08 Dec 2020   Prob (F-statistic):           5.74e-10
# Time:                        01:34:13   Log-Likelihood:                -93.597
# No. Observations:                  17   AIC:                             197.2
# Df Residuals:                      12   BIC:                             201.4
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -1.507e+04   2692.236     -5.598      0.000   -2.09e+04   -9206.331
# ...

# %%
data["Energy Consumption (Trillion BTU/ yr)"].plot()
# Out:
# <AxesSubplot:>
